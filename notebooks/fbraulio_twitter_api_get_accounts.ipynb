# %%
## https://towardsdatascience.com/an-extensive-guide-to-collecting-tweets-from-twitter-api-v2-for-academic-research-using-python-3-518fcb71df2a

import requests
import os
import json
import pandas as pd
import numpy as np
import csv
import datetime
import dateutil.parser
import unicodedata
import time
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
def auth():
    #return os.getenv('BEARER_TOKEN')

def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

def append_tweet_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for tweet in json_response['data']:
        
        # We will create a variable for each since some of the keys might not exist for some tweets
        # So we will account for that

        # 1. Author ID
        author_id = tweet['author_id']

        # 2. Time created
        created_at = dateutil.parser.parse(tweet['created_at'])

        # 3. Geolocation
        if ('geo' in tweet):   
            geo = tweet['geo']['place_id']
        else:
            geo = " "

        # 4. Tweet and Conversation ID
        tweet_id = tweet['id']
        conversation_id = tweet['conversation_id']

        # 5. Language
        lang = tweet['lang']

        # 6. Tweet metrics
        retweet_count = tweet['public_metrics']['retweet_count']
        reply_count = tweet['public_metrics']['reply_count']
        like_count = tweet['public_metrics']['like_count']
        quote_count = tweet['public_metrics']['quote_count']

        # 7. source
        source = tweet['source']

        # 8. Tweet text
        text = tweet['text']
        
        # Assemble all data in a list
        res = [tweet_id, conversation_id, author_id, created_at, geo, lang, like_count, quote_count, reply_count, retweet_count, source, text]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Tweets added from this response: ", counter) 
    
def append_user_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for user in json_response['includes']['users']:

        # 1. Author ID, Username and DisplayName
        author_id = user['id']
        username = user['username']
        display_name = user['name']

        # 2. Description
        description = user['description']
        
        # 3. Verified
        verified = user['verified']
        
        # 4. Time user created
        created_at = dateutil.parser.parse(user['created_at'])

        # 5. User metrics
        followers_count = user['public_metrics']['followers_count']
        following_count = user['public_metrics']['following_count']
        tweet_count = user['public_metrics']['tweet_count']
        listed_count = user['public_metrics']['listed_count']
        
        # Assemble all data in a list
        res = [author_id, username, display_name, description, verified, created_at, followers_count, following_count, tweet_count, listed_count]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of users added from this response: ", counter) 
    
def append_place_to_csv(json_response, fileName):

    #A counter variable
    counter = 0

    #Open OR create the target CSV file
    csvFile = open(fileName, "a", newline="", encoding='utf-8')
    csvWriter = csv.writer(csvFile)

    #Loop through each tweet
    for place in json_response['includes']['places']:

        # Features
        geo = place['id']
        full_name = place['full_name']
        place_type = place['place_type']
        name = place['name']
        country_code = place['country_code']
        
        # Assemble all data in a list
        res = [geo, full_name, place_type, name, country_code]
        
        # Append the result to the CSV file
        csvWriter.writerow(res)
        counter += 1

    # When done, close the CSV file
    csvFile.close()

    # Print the number of tweets for this iteration
    print("# of Places added from this response: ", counter)

# %%
'places' in json_response['includes'].keys()
# Out:
# False

# %%
# Create tweet file and write header
csvFile = open("./../data/processed/covid_tweets.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['tweet_id', 'conversation_id', 'author_id', 'created_at', 'geo', 'lang', 'like_count', 'quote_count', 'reply_count', 'retweet_count', 'source', 'text'])
csvFile.close()

# Create user file and write header
csvFile = open("./../data/processed/covid_users.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['author_id', 'username', 'display_name', 'description', 'verified', 'created_at', 'followers_count', 'following_count', 'tweet_count', 'listed_count'])
csvFile.close()

# Create place file and write header
csvFile = open("./../data/processed/covid_places.csv", "a", newline="", encoding='utf-8')
csvWriter = csv.writer(csvFile)
csvWriter.writerow(['geo', 'full_name', 'place_type', 'name', 'country_code'])
csvFile.close()

# Inputs for tweets
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "context:123.1220701888179359745 is:verified lang:en -is:retweet -is:reply"
start_date = '2020-12-01T00:00:00.000Z'
end_date = '2020-12-31T23:59:59.000Z'
max_results = 500

# Loop Inputs
total_tweets = 0
count = 0 # Counting tweets per time period
max_count = 1000000 # Max tweets per time period
flag = True
next_token = None
n_requests = 0

# Check if flag is true
start_time = time.time()

# %%
while flag:
    # Check if max_count reached
    if count >= max_count:
        break
    print("-------------------")
    print("Request #: ", n_requests+1)
    print("Requesting Time: ", int(time.time() - start_time))
    print("Token: ", next_token)
    url = create_url(keyword, start_date,end_date, max_results)
    json_response = connect_to_endpoint(url[0], headers, url[1], next_token)
    result_count = json_response['meta']['result_count']

    if 'next_token' in json_response['meta']:
        # Save the token to use for next call
        next_token = json_response['meta']['next_token']
        print("Next Token: ", next_token)
        if result_count is not None and result_count > 0 and next_token is not None:
            append_tweet_to_csv(json_response, "./../data/processed/covid_tweets.csv")
            append_user_to_csv(json_response, "./../data/processed/covid_users.csv")
            if 'places' in json_response['includes'].keys():
                append_place_to_csv(json_response, "./../data/processed/covid_places.csv")
            count += result_count
            total_tweets += result_count
            n_requests += 1
            print("Total # of Tweets added: ", total_tweets)
            print("-------------------")
            time.sleep(1)                
    # If no next token exists
    else:
        if result_count is not None and result_count > 0:
            print("-------------------")
            append_tweet_to_csv(json_response, "./../data/processed/covid_tweets.csv")
            append_user_to_csv(json_response, "./../data/processed/covid_users.csv")
            if 'places' in json_response['includes'].keys():
                append_place_to_csv(json_response, "./../data/processed/covid_places.csv")
            count += result_count
            total_tweets += result_count
            print("Total # of Tweets added: ", total_tweets)
            print("-------------------")
            time.sleep(1)

        #Since this is the final request, turn flag to false to move to the next time period.
        flag = False
        next_token = None
    time.sleep(1)
    # If reachs requests cap, stop it
    if n_requests%295==0 and time.time()-start_time<900:
        time.sleep(900 - (time.time()-start_time))
    elif n_requests%295==0  and time.time()-start_time>=900:
        start_time=time.time()
print("Total number of results: ", total_tweets)
# Out:
# -------------------
# Request #:  592
# Requesting Time:  861
# Token:  b26v89c19zqg8o3foshs43sql1wutqt6tg7kud2j0ymbh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs43sfvo7o2x52vujyb5frutb3x
# # of Tweets added from this response:  500
# # of users added from this response:  432
# # of Places added from this response:  5
# Total # of Tweets added:  295468
# -------------------
# -------------------
# Request #:  593
# Requesting Time:  865
# Token:  b26v89c19zqg8o3foshs43sfvo7o2x52vujyb5frutb3x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs43s56bczuz0otq63co3mev3i5
# # of Tweets added from this response:  500
# # of users added from this response:  435
# # of Places added from this response:  5
# Total # of Tweets added:  295968
# -------------------
# -------------------
# Request #:  594
# Requesting Time:  869
# Token:  b26v89c19zqg8o3foshs43s56bczuz0otq63co3mev3i5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs43rufe6ircn2k5215pn5pc1od
# # of Tweets added from this response:  500
# # of users added from this response:  425
# # of Places added from this response:  7
# Total # of Tweets added:  296468
# -------------------
# -------------------
# Request #:  595
# Requesting Time:  874
# Token:  b26v89c19zqg8o3foshs43rufe6ircn2k5215pn5pc1od
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs43rjrhly2oahnxqb30alirtkt
# # of Tweets added from this response:  500
# # of users added from this response:  415
# # of Places added from this response:  8
# Total # of Tweets added:  296968
# -------------------
# -------------------
# Request #:  596
# Requesting Time:  879
# Token:  b26v89c19zqg8o3foshs43rjrhly2oahnxqb30alirtkt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs43rjgv1fuve5zy5wdx2xfblod
# # of Tweets added from this response:  500
# # of users added from this response:  426
# # of Places added from this response:  6
# Total # of Tweets added:  297468
# -------------------
# -------------------
# Request #:  597
# Requesting Time:  883
# Token:  b26v89c19zqg8o3foshs43rjgv1fuve5zy5wdx2xfblod
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs43r8t0dzwoxtxby1bco6e8hod
# # of Tweets added from this response:  499
# # of users added from this response:  432
# # of Places added from this response:  4
# Total # of Tweets added:  297967
# -------------------
# -------------------
# Request #:  598
# Requesting Time:  888
# Token:  b26v89c19zqg8o3foshs43r8t0dzwoxtxby1bco6e8hod
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41p7xkv0qsfn0jafazp8n0ewt
# # of Tweets added from this response:  500
# # of users added from this response:  443
# # of Places added from this response:  7
# Total # of Tweets added:  298467
# -------------------
# -------------------
# Request #:  599
# Requesting Time:  892
# Token:  b26v89c19zqg8o3foshs41p7xkv0qsfn0jafazp8n0ewt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41p7ohjwr91yuurbz5pcna5x9
# # of Tweets added from this response:  498
# # of users added from this response:  451
# # of Places added from this response:  7
# Total # of Tweets added:  298965
# -------------------
# -------------------
# Request #:  600
# Requesting Time:  896
# Token:  b26v89c19zqg8o3foshs41p7ohjwr91yuurbz5pcna5x9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41ox24nz1z32ckjo1jm5of4ot
# # of Tweets added from this response:  499
# # of users added from this response:  429
# # of Places added from this response:  8
# Total # of Tweets added:  299464
# -------------------
# -------------------
# Request #:  601
# Requesting Time:  901
# Token:  b26v89c19zqg8o3foshs41ox24nz1z32ckjo1jm5of4ot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41owt1sgtqhcvps6b6gt8z88t
# # of Tweets added from this response:  500
# # of users added from this response:  465
# # of Places added from this response:  16
# Total # of Tweets added:  299964
# -------------------
# -------------------
# Request #:  602
# Requesting Time:  905
# Token:  b26v89c19zqg8o3foshs41owt1sgtqhcvps6b6gt8z88t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41om87bcn04wdh9yobrql2np9
# # of Tweets added from this response:  499
# # of users added from this response:  466
# # of Places added from this response:  15
# Total # of Tweets added:  300463
# -------------------
# -------------------
# Request #:  603
# Requesting Time:  909
# Token:  b26v89c19zqg8o3foshs41om87bcn04wdh9yobrql2np9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41om0m7agtr8vhc8szwkgc131
# # of Tweets added from this response:  499
# # of users added from this response:  469
# # of Places added from this response:  14
# Total # of Tweets added:  300962
# -------------------
# -------------------
# Request #:  604
# Requesting Time:  914
# Token:  b26v89c19zqg8o3foshs41om0m7agtr8vhc8szwkgc131
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41obfrxm891sh7kj97nlx6rnh
# # of Tweets added from this response:  497
# # of users added from this response:  450
# # of Places added from this response:  17
# Total # of Tweets added:  301459
# -------------------
# -------------------
# Request #:  605
# Requesting Time:  918
# Token:  b26v89c19zqg8o3foshs41obfrxm891sh7kj97nlx6rnh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41ob9pvczqc0sjqmib8i7s3nh
# # of Tweets added from this response:  499
# # of users added from this response:  467
# # of Places added from this response:  9
# Total # of Tweets added:  301958
# -------------------
# -------------------
# Request #:  606
# Requesting Time:  922
# Token:  b26v89c19zqg8o3foshs41ob9pvczqc0sjqmib8i7s3nh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41o0qdldvhai8l7m3gjcdjw59
# # of Tweets added from this response:  498
# # of users added from this response:  462
# # of Places added from this response:  10
# Total # of Tweets added:  302456
# -------------------
# -------------------
# Request #:  607
# Requesting Time:  926
# Token:  b26v89c19zqg8o3foshs41o0qdldvhai8l7m3gjcdjw59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41o0lsnnhnrm1dmk939milri5
# # of Tweets added from this response:  497
# # of users added from this response:  469
# # of Places added from this response:  11
# Total # of Tweets added:  302953
# -------------------
# -------------------
# Request #:  608
# Requesting Time:  931
# Token:  b26v89c19zqg8o3foshs41o0lsnnhnrm1dmk939milri5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41o0fq5xzxealq1sgb29vmk59
# # of Tweets added from this response:  498
# # of users added from this response:  469
# # of Places added from this response:  11
# Total # of Tweets added:  303451
# -------------------
# -------------------
# Request #:  609
# Requesting Time:  935
# Token:  b26v89c19zqg8o3foshs41o0fq5xzxealq1sgb29vmk59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41npwg8go92nwt7cdul0s2iyl
# # of Tweets added from this response:  499
# # of users added from this response:  484
# # of Places added from this response:  11
# Total # of Tweets added:  303950
# -------------------
# -------------------
# Request #:  610
# Requesting Time:  939
# Token:  b26v89c19zqg8o3foshs41npwg8go92nwt7cdul0s2iyl
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41npqdbg9gbsn0d9cg6z5pn5p
# # of Tweets added from this response:  497
# # of users added from this response:  461
# # of Places added from this response:  11
# Total # of Tweets added:  304447
# -------------------
# -------------------
# Request #:  611
# Requesting Time:  943
# Token:  b26v89c19zqg8o3foshs41npqdbg9gbsn0d9cg6z5pn5p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41nf71gqxuvabl7a9h3a81vnh
# # of Tweets added from this response:  500
# # of users added from this response:  471
# # of Places added from this response:  12
# Total # of Tweets added:  304947
# -------------------
# -------------------
# Request #:  612
# Requesting Time:  948
# Token:  b26v89c19zqg8o3foshs41nf71gqxuvabl7a9h3a81vnh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41nf0y4gr615lyksaeq8frfct
# # of Tweets added from this response:  499
# # of users added from this response:  460
# # of Places added from this response:  11
# Total # of Tweets added:  305446
# -------------------
# -------------------
# Request #:  613
# Requesting Time:  952
# Token:  b26v89c19zqg8o3foshs41nf0y4gr615lyksaeq8frfct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41newe1imtgcd3t50gym3xvgd
# # of Tweets added from this response:  499
# # of users added from this response:  468
# # of Places added from this response:  5
# Total # of Tweets added:  305945
# -------------------
# -------------------
# Request #:  614
# Requesting Time:  956
# Token:  b26v89c19zqg8o3foshs41newe1imtgcd3t50gym3xvgd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41n4bkuedyjxejyrh96eem7wd
# # of Tweets added from this response:  499
# # of users added from this response:  470
# # of Places added from this response:  6
# Total # of Tweets added:  306444
# -------------------
# -------------------
# Request #:  615
# Requesting Time:  960
# Token:  b26v89c19zqg8o3foshs41n4bkuedyjxejyrh96eem7wd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41n45haeknx2aqz5frn99q3ct
# # of Tweets added from this response:  500
# # of users added from this response:  469
# Total # of Tweets added:  306944
# -------------------
# -------------------
# Request #:  616
# Requesting Time:  965
# Token:  b26v89c19zqg8o3foshs41n45haeknx2aqz5frn99q3ct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41mtm5uz20sc8mlkxsrn8avzx
# # of Tweets added from this response:  499
# # of users added from this response:  471
# # of Places added from this response:  10
# Total # of Tweets added:  307443
# -------------------
# -------------------
# Request #:  617
# Requesting Time:  969
# Token:  b26v89c19zqg8o3foshs41mtm5uz20sc8mlkxsrn8avzx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41mtg4878n82oib1hy8f9z0jh
# # of Tweets added from this response:  499
# # of users added from this response:  480
# # of Places added from this response:  9
# Total # of Tweets added:  307942
# -------------------
# -------------------
# Request #:  618
# Requesting Time:  973
# Token:  b26v89c19zqg8o3foshs41mtg4878n82oib1hy8f9z0jh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41mta1iylgza6e0m3pwddzr0d
# # of Tweets added from this response:  500
# # of users added from this response:  469
# # of Places added from this response:  12
# Total # of Tweets added:  308442
# -------------------
# -------------------
# Request #:  619
# Requesting Time:  977
# Token:  b26v89c19zqg8o3foshs41mta1iylgza6e0m3pwddzr0d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41mis7fy0uregybbqipjl3v5p
# # of Tweets added from this response:  498
# # of users added from this response:  478
# # of Places added from this response:  11
# Total # of Tweets added:  308940
# -------------------
# -------------------
# Request #:  620
# Requesting Time:  982
# Token:  b26v89c19zqg8o3foshs41mis7fy0uregybbqipjl3v5p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41mim686a5dtlxdl5esrfr059
# # of Tweets added from this response:  500
# # of users added from this response:  488
# # of Places added from this response:  12
# Total # of Tweets added:  309440
# -------------------
# -------------------
# Request #:  621
# Requesting Time:  986
# Token:  b26v89c19zqg8o3foshs41mim686a5dtlxdl5esrfr059
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs41mihlxq4gtw02osm5xzfpbwd
# # of Tweets added from this response:  499
# # of users added from this response:  477
# # of Places added from this response:  7
# Total # of Tweets added:  309939
# -------------------
# -------------------
# Request #:  622
# Requesting Time:  990
# Token:  b26v89c19zqg8o3foshs41mihlxq4gtw02osm5xzfpbwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zkhp8i9mqo7erhee22tl5bi5
# # of Tweets added from this response:  499
# # of users added from this response:  477
# # of Places added from this response:  11
# Total # of Tweets added:  310438
# -------------------
# -------------------
# Request #:  623
# Requesting Time:  995
# Token:  b26v89c19zqg8o3foshs3zkhp8i9mqo7erhee22tl5bi5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zkhko7th1srmkib3w9aw4dbx
# # of Tweets added from this response:  500
# # of users added from this response:  483
# # of Places added from this response:  9
# Total # of Tweets added:  310938
# -------------------
# -------------------
# Request #:  624
# Requesting Time:  999
# Token:  b26v89c19zqg8o3foshs3zkhko7th1srmkib3w9aw4dbx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zkhemsjp5t2yim1dds2ow325
# # of Tweets added from this response:  499
# # of users added from this response:  481
# # of Places added from this response:  6
# Total # of Tweets added:  311437
# -------------------
# -------------------
# Request #:  625
# Requesting Time:  1003
# Token:  b26v89c19zqg8o3foshs3zkhemsjp5t2yim1dds2ow325
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zk6yawkvryto4rs26y7wgsjh
# # of Tweets added from this response:  498
# # of users added from this response:  476
# # of Places added from this response:  6
# Total # of Tweets added:  311935
# -------------------
# -------------------
# Request #:  626
# Requesting Time:  1008
# Token:  b26v89c19zqg8o3foshs3zk6yawkvryto4rs26y7wgsjh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zk6s9hc72um7164m1ogtuu7x
# # of Tweets added from this response:  499
# # of users added from this response:  474
# # of Places added from this response:  6
# Total # of Tweets added:  312434
# -------------------
# -------------------
# Request #:  627
# Requesting Time:  1012
# Token:  b26v89c19zqg8o3foshs3zk6s9hc72um7164m1ogtuu7x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zk6npebwyeb70r5a7b3lvs71
# # of Tweets added from this response:  499
# # of users added from this response:  457
# # of Places added from this response:  5
# Total # of Tweets added:  312933
# -------------------
# -------------------
# Request #:  628
# Requesting Time:  1016
# Token:  b26v89c19zqg8o3foshs3zk6npebwyeb70r5a7b3lvs71
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjw5wszs3sr81pydel6si5q5
# # of Tweets added from this response:  500
# # of users added from this response:  473
# # of Places added from this response:  7
# Total # of Tweets added:  313433
# -------------------
# -------------------
# Request #:  629
# Requesting Time:  1021
# Token:  b26v89c19zqg8o3foshs3zjw5wszs3sr81pydel6si5q5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjw1d5k4ezm03drjim9fctq5
# # of Tweets added from this response:  500
# # of users added from this response:  471
# # of Places added from this response:  7
# Total # of Tweets added:  313933
# -------------------
# -------------------
# Request #:  630
# Requesting Time:  1025
# Token:  b26v89c19zqg8o3foshs3zjw1d5k4ezm03drjim9fctq5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjvybh91lhsuo3l9n9slyr25
# # of Tweets added from this response:  499
# # of users added from this response:  483
# # of Places added from this response:  10
# Total # of Tweets added:  314432
# -------------------
# -------------------
# Request #:  631
# Requesting Time:  1029
# Token:  b26v89c19zqg8o3foshs3zjvybh91lhsuo3l9n9slyr25
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjvv960qytfrd08lwuqg9b3x
# # of Tweets added from this response:  500
# # of users added from this response:  485
# # of Places added from this response:  7
# Total # of Tweets added:  314932
# -------------------
# -------------------
# Request #:  632
# Requesting Time:  1034
# Token:  b26v89c19zqg8o3foshs3zjvv960qytfrd08lwuqg9b3x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjldfxvnpob70rakufj30znh
# # of Tweets added from this response:  499
# # of users added from this response:  471
# # of Places added from this response:  9
# Total # of Tweets added:  315431
# -------------------
# -------------------
# Request #:  633
# Requesting Time:  1038
# Token:  b26v89c19zqg8o3foshs3zjldfxvnpob70rakufj30znh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjl8xcreh3zalye38c8nkvi5
# # of Tweets added from this response:  499
# # of users added from this response:  484
# # of Places added from this response:  9
# Total # of Tweets added:  315930
# -------------------
# -------------------
# Request #:  634
# Requesting Time:  1042
# Token:  b26v89c19zqg8o3foshs3zjl8xcreh3zalye38c8nkvi5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjl4d9r53xp29mr70w7sv1bx
# # of Tweets added from this response:  499
# # of users added from this response:  475
# # of Places added from this response:  9
# Total # of Tweets added:  316429
# -------------------
# -------------------
# Request #:  635
# Requesting Time:  1046
# Token:  b26v89c19zqg8o3foshs3zjl4d9r53xp29mr70w7sv1bx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjamkgwym957tdoxg30wqirh
# # of Tweets added from this response:  499
# # of users added from this response:  465
# # of Places added from this response:  8
# Total # of Tweets added:  316928
# -------------------
# -------------------
# Request #:  636
# Requesting Time:  1051
# Token:  b26v89c19zqg8o3foshs3zjamkgwym957tdoxg30wqirh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjajj826dubp0ehaw264xb3x
# # of Tweets added from this response:  499
# # of users added from this response:  494
# # of Places added from this response:  7
# Total # of Tweets added:  317427
# -------------------
# -------------------
# Request #:  637
# Requesting Time:  1055
# Token:  b26v89c19zqg8o3foshs3zjajj826dubp0ehaw264xb3x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjaez542n3fpiz5jm8cqtr3x
# # of Tweets added from this response:  500
# # of users added from this response:  482
# # of Places added from this response:  9
# Total # of Tweets added:  317927
# -------------------
# -------------------
# Request #:  638
# Requesting Time:  1059
# Token:  b26v89c19zqg8o3foshs3zjaez542n3fpiz5jm8cqtr3x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zjaaf9r8qth7go1hoqx0oi2l
# # of Tweets added from this response:  500
# # of users added from this response:  475
# # of Places added from this response:  11
# Total # of Tweets added:  318427
# -------------------
# -------------------
# Request #:  639
# Requesting Time:  1064
# Token:  b26v89c19zqg8o3foshs3zjaaf9r8qth7go1hoqx0oi2l
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zizsm9dxf4wpibdgg8qppq4d
# # of Tweets added from this response:  499
# # of users added from this response:  474
# # of Places added from this response:  5
# Total # of Tweets added:  318926
# -------------------
# -------------------
# Request #:  640
# Requesting Time:  1068
# Token:  b26v89c19zqg8o3foshs3zizsm9dxf4wpibdgg8qppq4d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zizo2thf0miin2rjwkefhm65
# # of Tweets added from this response:  499
# # of users added from this response:  479
# # of Places added from this response:  10
# Total # of Tweets added:  319425
# -------------------
# -------------------
# Request #:  641
# Requesting Time:  1072
# Token:  b26v89c19zqg8o3foshs3zizo2thf0miin2rjwkefhm65
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zizl0xgqynlmjfxc7mkcf1bx
# # of Tweets added from this response:  498
# # of users added from this response:  477
# # of Places added from this response:  10
# Total # of Tweets added:  319923
# -------------------
# -------------------
# Request #:  642
# Requesting Time:  1077
# Token:  b26v89c19zqg8o3foshs3zizl0xgqynlmjfxc7mkcf1bx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zizhz9c6zbm5y2wmbryceovx
# # of Tweets added from this response:  499
# # of users added from this response:  481
# # of Places added from this response:  8
# Total # of Tweets added:  320422
# -------------------
# -------------------
# Request #:  643
# Requesting Time:  1081
# Token:  b26v89c19zqg8o3foshs3zizhz9c6zbm5y2wmbryceovx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zip068vmoxlc2i9yp1tqxo59
# # of Tweets added from this response:  500
# # of users added from this response:  471
# # of Places added from this response:  12
# Total # of Tweets added:  320922
# -------------------
# -------------------
# Request #:  644
# Requesting Time:  1086
# Token:  b26v89c19zqg8o3foshs3zip068vmoxlc2i9yp1tqxo59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3ziovnfxgo4cs2b4plueu35od
# # of Tweets added from this response:  500
# # of users added from this response:  473
# # of Places added from this response:  11
# Total # of Tweets added:  321422
# -------------------
# -------------------
# Request #:  645
# Requesting Time:  1090
# Token:  b26v89c19zqg8o3foshs3ziovnfxgo4cs2b4plueu35od
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zioskx1ol7znnfs6ozfuettp
# # of Tweets added from this response:  500
# # of users added from this response:  475
# # of Places added from this response:  11
# Total # of Tweets added:  321922
# -------------------
# -------------------
# Request #:  646
# Requesting Time:  1094
# Token:  b26v89c19zqg8o3foshs3zioskx1ol7znnfs6ozfuettp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zioo2bs1iwm379a3jwdf3ssd
# # of Tweets added from this response:  499
# # of users added from this response:  482
# # of Places added from this response:  8
# Total # of Tweets added:  322421
# -------------------
# -------------------
# Request #:  647
# Requesting Time:  1099
# Token:  b26v89c19zqg8o3foshs3zioo2bs1iwm379a3jwdf3ssd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zie7raqwhumo3ldjzivtldh9
# # of Tweets added from this response:  500
# # of users added from this response:  483
# # of Places added from this response:  3
# Total # of Tweets added:  322921
# -------------------
# -------------------
# Request #:  648
# Requesting Time:  1103
# Token:  b26v89c19zqg8o3foshs3zie7raqwhumo3ldjzivtldh9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zie4qha9iytb1t8sb1tv0gvx
# # of Tweets added from this response:  499
# # of users added from this response:  485
# # of Places added from this response:  6
# Total # of Tweets added:  323420
# -------------------
# -------------------
# Request #:  649
# Requesting Time:  1108
# Token:  b26v89c19zqg8o3foshs3zie4qha9iytb1t8sb1tv0gvx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zie1odgs6gcomunrnlztiyrh
# # of Tweets added from this response:  500
# # of users added from this response:  481
# # of Places added from this response:  14
# Total # of Tweets added:  323920
# -------------------
# -------------------
# Request #:  650
# Requesting Time:  1112
# Token:  b26v89c19zqg8o3foshs3zie1odgs6gcomunrnlztiyrh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zidx4q6i09lhw6efd30f63jx
# # of Tweets added from this response:  499
# # of users added from this response:  476
# # of Places added from this response:  6
# Total # of Tweets added:  324419
# -------------------
# -------------------
# Request #:  651
# Requesting Time:  1117
# Token:  b26v89c19zqg8o3foshs3zidx4q6i09lhw6efd30f63jx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zi3gtwes4xzh2v5ks6gzhn5p
# # of Tweets added from this response:  500
# # of users added from this response:  486
# # of Places added from this response:  8
# Total # of Tweets added:  324919
# -------------------
# -------------------
# Request #:  652
# Requesting Time:  1121
# Token:  b26v89c19zqg8o3foshs3zi3gtwes4xzh2v5ks6gzhn5p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zi3cagnnpngxztw68jaon7gd
# # of Tweets added from this response:  498
# # of users added from this response:  472
# # of Places added from this response:  11
# Total # of Tweets added:  325417
# -------------------
# -------------------
# Request #:  653
# Requesting Time:  1125
# Token:  b26v89c19zqg8o3foshs3zi3cagnnpngxztw68jaon7gd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zi398d0n828jq9bxxu6pddod
# # of Tweets added from this response:  499
# # of users added from this response:  482
# # of Places added from this response:  6
# Total # of Tweets added:  325916
# -------------------
# -------------------
# Request #:  654
# Requesting Time:  1130
# Token:  b26v89c19zqg8o3foshs3zi398d0n828jq9bxxu6pddod
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zi3686r0hj2t65j4dwo0dgfx
# # of Tweets added from this response:  500
# # of users added from this response:  487
# # of Places added from this response:  6
# Total # of Tweets added:  326416
# -------------------
# -------------------
# Request #:  655
# Requesting Time:  1134
# Token:  b26v89c19zqg8o3foshs3zi3686r0hj2t65j4dwo0dgfx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zhsoflfy7re1adhc6xr322rh
# # of Tweets added from this response:  500
# # of users added from this response:  475
# # of Places added from this response:  11
# Total # of Tweets added:  326916
# -------------------
# -------------------
# Request #:  656
# Requesting Time:  1138
# Token:  b26v89c19zqg8o3foshs3zhsoflfy7re1adhc6xr322rh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zhsldpgdsxxzwu4n0md6dnct
# # of Tweets added from this response:  499
# # of users added from this response:  475
# # of Places added from this response:  7
# Total # of Tweets added:  327415
# -------------------
# -------------------
# Request #:  657
# Requesting Time:  1143
# Token:  b26v89c19zqg8o3foshs3zhsldpgdsxxzwu4n0md6dnct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zhsic91f7w7bph7tr6xqzyil
# # of Tweets added from this response:  500
# # of users added from this response:  476
# # of Places added from this response:  8
# Total # of Tweets added:  327915
# -------------------
# -------------------
# Request #:  658
# Requesting Time:  1147
# Token:  b26v89c19zqg8o3foshs3zhsic91f7w7bph7tr6xqzyil
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zhsdsdw5j5ss0nnr51ngv0jh
# # of Tweets added from this response:  500
# # of users added from this response:  482
# # of Places added from this response:  9
# Total # of Tweets added:  328415
# -------------------
# -------------------
# Request #:  659
# Requesting Time:  1151
# Token:  b26v89c19zqg8o3foshs3zhsdsdw5j5ss0nnr51ngv0jh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3zhsaqhs8ib9bpzay129j9z7h
# # of Tweets added from this response:  497
# # of users added from this response:  468
# # of Places added from this response:  9
# Total # of Tweets added:  328912
# -------------------
# -------------------
# Request #:  660
# Requesting Time:  1155
# Token:  b26v89c19zqg8o3foshs3zhsaqhs8ib9bpzay129j9z7h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfrle3qm8jq3lrfad7y5lvul
# # of Tweets added from this response:  500
# # of users added from this response:  479
# # of Places added from this response:  6
# Total # of Tweets added:  329412
# -------------------
# -------------------
# Request #:  661
# Requesting Time:  1160
# Token:  b26v89c19zqg8o3foshs3xfrle3qm8jq3lrfad7y5lvul
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfrgv3bhlyajstgckn5zj0ql
# # of Tweets added from this response:  499
# # of users added from this response:  481
# # of Places added from this response:  7
# Total # of Tweets added:  329911
# -------------------
# -------------------
# Request #:  662
# Requesting Time:  1164
# Token:  b26v89c19zqg8o3foshs3xfrgv3bhlyajstgckn5zj0ql
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfrcbuwzxqhgeus7clmhh119
# # of Tweets added from this response:  500
# # of users added from this response:  477
# # of Places added from this response:  15
# Total # of Tweets added:  330411
# -------------------
# -------------------
# Request #:  663
# Requesting Time:  1168
# Token:  b26v89c19zqg8o3foshs3xfrcbuwzxqhgeus7clmhh119
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfr99c6n7i8f9082iuo7z6v1
# # of Tweets added from this response:  500
# # of users added from this response:  482
# # of Places added from this response:  5
# Total # of Tweets added:  330911
# -------------------
# -------------------
# Request #:  664
# Requesting Time:  1173
# Token:  b26v89c19zqg8o3foshs3xfr99c6n7i8f9082iuo7z6v1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfgrg3v26iw9gaa5sz2mnrel
# # of Tweets added from this response:  499
# # of users added from this response:  469
# # of Places added from this response:  10
# Total # of Tweets added:  331410
# -------------------
# -------------------
# Request #:  665
# Requesting Time:  1177
# Token:  b26v89c19zqg8o3foshs3xfgrg3v26iw9gaa5sz2mnrel
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfgmx3793anw3e1y369x0scd
# # of Tweets added from this response:  498
# # of users added from this response:  462
# # of Places added from this response:  9
# Total # of Tweets added:  331908
# -------------------
# -------------------
# Request #:  666
# Requesting Time:  1181
# Token:  b26v89c19zqg8o3foshs3xfgmx3793anw3e1y369x0scd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xfgjw9uyvp3uzl1rarvzo399
# # of Tweets added from this response:  499
# # of users added from this response:  489
# # of Places added from this response:  6
# Total # of Tweets added:  332407
# -------------------
# -------------------
# Request #:  667
# Requesting Time:  1186
# Token:  b26v89c19zqg8o3foshs3xfgjw9uyvp3uzl1rarvzo399
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xf622tuvcpkcn9wzer1629h9
# # of Tweets added from this response:  499
# # of users added from this response:  475
# # of Places added from this response:  10
# Total # of Tweets added:  332906
# -------------------
# -------------------
# Request #:  668
# Requesting Time:  1190
# Token:  b26v89c19zqg8o3foshs3xf622tuvcpkcn9wzer1629h9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xf5xi42rjc3vs5po6z6dg4u5
# # of Tweets added from this response:  498
# # of users added from this response:  456
# # of Places added from this response:  11
# Total # of Tweets added:  333404
# -------------------
# -------------------
# Request #:  669
# Requesting Time:  1195
# Token:  b26v89c19zqg8o3foshs3xf5xi42rjc3vs5po6z6dg4u5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xf5sy15px6nrmc8qg9s78v3x
# # of Tweets added from this response:  500
# # of users added from this response:  466
# # of Places added from this response:  8
# Total # of Tweets added:  333904
# -------------------
# -------------------
# Request #:  670
# Requesting Time:  1199
# Token:  b26v89c19zqg8o3foshs3xf5sy15px6nrmc8qg9s78v3x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xev9nvsb2p08qhsc5ida4inx
# # of Tweets added from this response:  499
# # of users added from this response:  470
# # of Places added from this response:  9
# Total # of Tweets added:  334403
# -------------------
# -------------------
# Request #:  671
# Requesting Time:  1204
# Token:  b26v89c19zqg8o3foshs3xev9nvsb2p08qhsc5ida4inx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xev6muqeprmfduz7yidfw2nx
# # of Tweets added from this response:  500
# # of users added from this response:  474
# # of Places added from this response:  3
# Total # of Tweets added:  334903
# -------------------
# -------------------
# Request #:  672
# Requesting Time:  1208
# Token:  b26v89c19zqg8o3foshs3xev6muqeprmfduz7yidfw2nx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xev0ivcfurw6ipw795wjxzel
# # of Tweets added from this response:  498
# # of users added from this response:  434
# # of Places added from this response:  13
# Total # of Tweets added:  335401
# -------------------
# -------------------
# Request #:  673
# Requesting Time:  1212
# Token:  b26v89c19zqg8o3foshs3xev0ivcfurw6ipw795wjxzel
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xeuvysb3lpcvjj6y0xogt37h
# # of Tweets added from this response:  499
# # of users added from this response:  458
# # of Places added from this response:  9
# Total # of Tweets added:  335900
# -------------------
# -------------------
# Request #:  674
# Requesting Time:  1217
# Token:  b26v89c19zqg8o3foshs3xeuvysb3lpcvjj6y0xogt37h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xekb68ewy4rw6owv2gf0xvgd
# # of Tweets added from this response:  500
# # of users added from this response:  447
# # of Places added from this response:  11
# Total # of Tweets added:  336400
# -------------------
# -------------------
# Request #:  675
# Requesting Time:  1221
# Token:  b26v89c19zqg8o3foshs3xekb68ewy4rw6owv2gf0xvgd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xek6m5iydd7iagj25lo01svx
# # of Tweets added from this response:  500
# # of users added from this response:  472
# # of Places added from this response:  6
# Total # of Tweets added:  336900
# -------------------
# -------------------
# Request #:  676
# Requesting Time:  1225
# Token:  b26v89c19zqg8o3foshs3xek6m5iydd7iagj25lo01svx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xe9n9fz7dmylu3fd4asmqet9
# # of Tweets added from this response:  498
# # of users added from this response:  457
# # of Places added from this response:  9
# Total # of Tweets added:  337398
# -------------------
# -------------------
# Request #:  677
# Requesting Time:  1229
# Token:  b26v89c19zqg8o3foshs3xe9n9fz7dmylu3fd4asmqet9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xe9h6itfddlgxoot4d2dgscd
# # of Tweets added from this response:  500
# # of users added from this response:  475
# # of Places added from this response:  6
# Total # of Tweets added:  337898
# -------------------
# -------------------
# Request #:  678
# Requesting Time:  1234
# Token:  b26v89c19zqg8o3foshs3xe9h6itfddlgxoot4d2dgscd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdyuvka76f9wea4n5h24jszh
# # of Tweets added from this response:  499
# # of users added from this response:  442
# # of Places added from this response:  9
# Total # of Tweets added:  338397
# -------------------
# -------------------
# Request #:  679
# Requesting Time:  1238
# Token:  b26v89c19zqg8o3foshs3xdyuvka76f9wea4n5h24jszh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdyq9ruspkpnnigb7kxxbo1p
# # of Tweets added from this response:  497
# # of users added from this response:  447
# # of Places added from this response:  9
# Total # of Tweets added:  338894
# -------------------
# -------------------
# Request #:  680
# Requesting Time:  1242
# Token:  b26v89c19zqg8o3foshs3xdyq9ruspkpnnigb7kxxbo1p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdyip31bowiszoothx6m1px9
# # of Tweets added from this response:  500
# # of users added from this response:  455
# # of Places added from this response:  9
# Total # of Tweets added:  339394
# -------------------
# -------------------
# Request #:  681
# Requesting Time:  1247
# Token:  b26v89c19zqg8o3foshs3xdyip31bowiszoothx6m1px9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdnxulzck83f3nvz7qeialbx
# # of Tweets added from this response:  498
# # of users added from this response:  447
# # of Places added from this response:  9
# Total # of Tweets added:  339892
# -------------------
# -------------------
# Request #:  682
# Requesting Time:  1251
# Token:  b26v89c19zqg8o3foshs3xdnxulzck83f3nvz7qeialbx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdnqacsocx91egzpuv34k48t
# # of Tweets added from this response:  500
# # of users added from this response:  459
# # of Places added from this response:  10
# Total # of Tweets added:  340392
# -------------------
# -------------------
# Request #:  683
# Requesting Time:  1255
# Token:  b26v89c19zqg8o3foshs3xdnqacsocx91egzpuv34k48t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdd5f8fed6s3sow66z53bukd
# # of Tweets added from this response:  500
# # of users added from this response:  448
# # of Places added from this response:  6
# Total # of Tweets added:  340892
# -------------------
# -------------------
# Request #:  684
# Requesting Time:  1259
# Token:  b26v89c19zqg8o3foshs3xdd5f8fed6s3sow66z53bukd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xdcxtwquuf5kwtkttu929w1p
# # of Tweets added from this response:  494
# # of users added from this response:  442
# # of Places added from this response:  6
# Total # of Tweets added:  341386
# -------------------
# -------------------
# Request #:  685
# Requesting Time:  1264
# Token:  b26v89c19zqg8o3foshs3xdcxtwquuf5kwtkttu929w1p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3xd2d0pu5qgs30qgclj9ea35p
# # of Tweets added from this response:  500
# # of users added from this response:  451
# # of Places added from this response:  5
# Total # of Tweets added:  341886
# -------------------
# -------------------
# Request #:  686
# Requesting Time:  1268
# Token:  b26v89c19zqg8o3foshs3xd2d0pu5qgs30qgclj9ea35p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3vb1hmh2gjfny2k3gwu3k16kd
# # of Tweets added from this response:  500
# # of users added from this response:  437
# # of Places added from this response:  4
# Total # of Tweets added:  342386
# -------------------
# -------------------
# Request #:  687
# Requesting Time:  1273
# Token:  b26v89c19zqg8o3foshs3vb1hmh2gjfny2k3gwu3k16kd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3vb18i3kyr3wqzhsj2p4i5yt9
# # of Tweets added from this response:  499
# # of users added from this response:  408
# # of Places added from this response:  5
# Total # of Tweets added:  342885
# -------------------
# -------------------
# Request #:  688
# Requesting Time:  1277
# Token:  b26v89c19zqg8o3foshs3vb18i3kyr3wqzhsj2p4i5yt9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3vaqm5n1el5m6dg9490qlie0t
# # of Tweets added from this response:  500
# # of users added from this response:  429
# # of Places added from this response:  7
# Total # of Tweets added:  343385
# -------------------
# -------------------
# Request #:  689
# Requesting Time:  1281
# Token:  b26v89c19zqg8o3foshs3vaqm5n1el5m6dg9490qlie0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3vaqd0ets1tkd8j40p5efh7ct
# # of Tweets added from this response:  500
# # of users added from this response:  424
# # of Places added from this response:  3
# Total # of Tweets added:  343885
# -------------------
# -------------------
# Request #:  690
# Requesting Time:  1285
# Token:  b26v89c19zqg8o3foshs3vaqd0ets1tkd8j40p5efh7ct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3vafp66op9gmvwjynejzt9nct
# # of Tweets added from this response:  499
# # of users added from this response:  424
# # of Places added from this response:  9
# Total # of Tweets added:  344384
# -------------------
# -------------------
# Request #:  691
# Requesting Time:  1290
# Token:  b26v89c19zqg8o3foshs3vafp66op9gmvwjynejzt9nct
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3va51aoecanj944bsgv3ye0l9
# # of Tweets added from this response:  500
# # of users added from this response:  434
# # of Places added from this response:  6
# Total # of Tweets added:  344884
# -------------------
# -------------------
# Request #:  692
# Requesting Time:  1294
# Token:  b26v89c19zqg8o3foshs3va51aoecanj944bsgv3ye0l9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3va4qoqq5bupw1oupvmd77ipp
# # of Tweets added from this response:  500
# # of users added from this response:  435
# # of Places added from this response:  6
# Total # of Tweets added:  345384
# -------------------
# -------------------
# Request #:  693
# Requesting Time:  1298
# Token:  b26v89c19zqg8o3foshs3va4qoqq5bupw1oupvmd77ipp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v9u2t8hx89dlw1w8rmecvp8d
# # of Tweets added from this response:  499
# # of users added from this response:  443
# # of Places added from this response:  4
# Total # of Tweets added:  345883
# -------------------
# -------------------
# Request #:  694
# Requesting Time:  1303
# Token:  b26v89c19zqg8o3foshs3v9u2t8hx89dlw1w8rmecvp8d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v9jhx1xkh7y99bud8j2o3pml
# # of Tweets added from this response:  500
# # of users added from this response:  450
# # of Places added from this response:  10
# Total # of Tweets added:  346383
# -------------------
# -------------------
# Request #:  695
# Requesting Time:  1307
# Token:  b26v89c19zqg8o3foshs3v9jhx1xkh7y99bud8j2o3pml
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v9jbvf4mul7apvf2mviws9z1
# # of Tweets added from this response:  499
# # of users added from this response:  470
# # of Places added from this response:  7
# Total # of Tweets added:  346882
# -------------------
# -------------------
# Request #:  696
# Requesting Time:  1311
# Token:  b26v89c19zqg8o3foshs3v9jbvf4mul7apvf2mviws9z1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v98r1dbdhkrtj400ye7a74ot
# # of Tweets added from this response:  499
# # of users added from this response:  464
# # of Places added from this response:  8
# Total # of Tweets added:  347381
# -------------------
# -------------------
# Request #:  697
# Requesting Time:  1316
# Token:  b26v89c19zqg8o3foshs3v98r1dbdhkrtj400ye7a74ot
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v98hx7hb5zzn1ywwemsrae7x
# # of Tweets added from this response:  499
# # of users added from this response:  440
# # of Places added from this response:  10
# Total # of Tweets added:  347880
# -------------------
# -------------------
# Request #:  698
# Requesting Time:  1320
# Token:  b26v89c19zqg8o3foshs3v98hx7hb5zzn1ywwemsrae7x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8xx2az0jma0nlgoy62fykcd
# # of Tweets added from this response:  499
# # of users added from this response:  462
# # of Places added from this response:  8
# Total # of Tweets added:  348379
# -------------------
# -------------------
# Request #:  699
# Requesting Time:  1325
# Token:  b26v89c19zqg8o3foshs3v8xx2az0jma0nlgoy62fykcd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8xo0hnulgssyb9sjzivilj1
# # of Tweets added from this response:  499
# # of users added from this response:  463
# # of Places added from this response:  16
# Total # of Tweets added:  348878
# -------------------
# -------------------
# Request #:  700
# Requesting Time:  1329
# Token:  b26v89c19zqg8o3foshs3v8xo0hnulgssyb9sjzivilj1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8n34iv90jlxapxans5uq64d
# # of Tweets added from this response:  500
# # of users added from this response:  455
# # of Places added from this response:  10
# Total # of Tweets added:  349378
# -------------------
# -------------------
# Request #:  701
# Requesting Time:  1334
# Token:  b26v89c19zqg8o3foshs3v8n34iv90jlxapxans5uq64d
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8mx214oe702w6bk9udlhlz1
# # of Tweets added from this response:  500
# # of users added from this response:  466
# # of Places added from this response:  8
# Total # of Tweets added:  349878
# -------------------
# -------------------
# Request #:  702
# Requesting Time:  1338
# Token:  b26v89c19zqg8o3foshs3v8mx214oe702w6bk9udlhlz1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8cdqtgxdiszs0v4qkcapym5
# # of Tweets added from this response:  500
# # of users added from this response:  454
# # of Places added from this response:  10
# Total # of Tweets added:  350378
# -------------------
# -------------------
# Request #:  703
# Requesting Time:  1342
# Token:  b26v89c19zqg8o3foshs3v8cdqtgxdiszs0v4qkcapym5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8c96y68y5uu1motessinh4t
# # of Tweets added from this response:  499
# # of users added from this response:  463
# # of Places added from this response:  8
# Total # of Tweets added:  350877
# -------------------
# -------------------
# Request #:  704
# Requesting Time:  1347
# Token:  b26v89c19zqg8o3foshs3v8c96y68y5uu1motessinh4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3v8c33tnt9v9qt3e0s7mjox31
# # of Tweets added from this response:  499
# # of users added from this response:  452
# # of Places added from this response:  10
# Total # of Tweets added:  351376
# -------------------
# -------------------
# Request #:  705
# Requesting Time:  1351
# Token:  b26v89c19zqg8o3foshs3v8c33tnt9v9qt3e0s7mjox31
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t6b999mcahy2vkip74iy0ebh
# # of Tweets added from this response:  498
# # of users added from this response:  462
# # of Places added from this response:  10
# Total # of Tweets added:  351874
# -------------------
# -------------------
# Request #:  706
# Requesting Time:  1355
# Token:  b26v89c19zqg8o3foshs3t6b999mcahy2vkip74iy0ebh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t6b35x6r0jnnv9oq6dsuwfwd
# # of Tweets added from this response:  499
# # of users added from this response:  467
# # of Places added from this response:  13
# Total # of Tweets added:  352373
# -------------------
# -------------------
# Request #:  707
# Requesting Time:  1359
# Token:  b26v89c19zqg8o3foshs3t6b35x6r0jnnv9oq6dsuwfwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t60iat35bsrciknp96zefxq5
# # of Tweets added from this response:  500
# # of users added from this response:  469
# # of Places added from this response:  5
# Total # of Tweets added:  352873
# -------------------
# -------------------
# Request #:  708
# Requesting Time:  1364
# Token:  b26v89c19zqg8o3foshs3t60iat35bsrciknp96zefxq5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t60c8qtysa1yyj0gtfnbptod
# # of Tweets added from this response:  498
# # of users added from this response:  473
# # of Places added from this response:  14
# Total # of Tweets added:  353371
# -------------------
# -------------------
# Request #:  709
# Requesting Time:  1368
# Token:  b26v89c19zqg8o3foshs3t60c8qtysa1yyj0gtfnbptod
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t5prfc4fbmpiudmjvyoloxh9
# # of Tweets added from this response:  499
# # of users added from this response:  459
# # of Places added from this response:  24
# Total # of Tweets added:  353870
# -------------------
# -------------------
# Request #:  710
# Requesting Time:  1373
# Token:  b26v89c19zqg8o3foshs3t5prfc4fbmpiudmjvyoloxh9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t5plcuh2r3bgvoemjlxwrxbx
# # of Tweets added from this response:  500
# # of users added from this response:  477
# # of Places added from this response:  8
# Total # of Tweets added:  354370
# -------------------
# -------------------
# Request #:  711
# Requesting Time:  1377
# Token:  b26v89c19zqg8o3foshs3t5plcuh2r3bgvoemjlxwrxbx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t5pgroyy2q7cp612hbr6jybh
# # of Tweets added from this response:  500
# # of users added from this response:  470
# # of Places added from this response:  11
# Total # of Tweets added:  354870
# -------------------
# -------------------
# Request #:  712
# Requesting Time:  1381
# Token:  b26v89c19zqg8o3foshs3t5pgroyy2q7cp612hbr6jybh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t5exgwxzpw6xu9baqxs9ba7x
# # of Tweets added from this response:  500
# # of users added from this response:  467
# # of Places added from this response:  5
# Total # of Tweets added:  355370
# -------------------
# -------------------
# Request #:  713
# Requesting Time:  1386
# Token:  b26v89c19zqg8o3foshs3t5exgwxzpw6xu9baqxs9ba7x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t5erdzwi6z7dzteyufwesqkd
# # of Tweets added from this response:  498
# # of users added from this response:  464
# # of Places added from this response:  10
# Total # of Tweets added:  355868
# -------------------
# -------------------
# Request #:  714
# Requesting Time:  1390
# Token:  b26v89c19zqg8o3foshs3t5erdzwi6z7dzteyufwesqkd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t5elbxl5q0ac327q0olbaa9p
# # of Tweets added from this response:  498
# # of users added from this response:  471
# # of Places added from this response:  7
# Total # of Tweets added:  356366
# -------------------
# -------------------
# Request #:  715
# Requesting Time:  1394
# Token:  b26v89c19zqg8o3foshs3t5elbxl5q0ac327q0olbaa9p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t543iwrmc7r623mj8jxpfon1
# # of Tweets added from this response:  498
# # of users added from this response:  446
# # of Places added from this response:  14
# Total # of Tweets added:  356864
# -------------------
# -------------------
# Request #:  716
# Requesting Time:  1399
# Token:  b26v89c19zqg8o3foshs3t543iwrmc7r623mj8jxpfon1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t53yzh0h5ine47816nziizjx
# # of Tweets added from this response:  498
# # of users added from this response:  469
# # of Places added from this response:  2
# Total # of Tweets added:  357362
# -------------------
# -------------------
# Request #:  717
# Requesting Time:  1403
# Token:  b26v89c19zqg8o3foshs3t53yzh0h5ine47816nziizjx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t53uejeg3jzzbnz9u3kefbzx
# # of Tweets added from this response:  500
# # of users added from this response:  474
# # of Places added from this response:  11
# Total # of Tweets added:  357862
# -------------------
# -------------------
# Request #:  718
# Requesting Time:  1408
# Token:  b26v89c19zqg8o3foshs3t53uejeg3jzzbnz9u3kefbzx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foshs3t4tclqfxwmsomxdjw6077mnx
# # of Tweets added from this response:  498
# ...
# -------------------
# -------------------
# Request #:  1963
# Requesting Time:  834
# Token:  b26v89c19zqg8o3foseufp4fjxgn5xv3uocv7ciaybn99
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufp4fdtwhxwlq7ru37cg001o59
# # of Tweets added from this response:  500
# # of users added from this response:  466
# # of Places added from this response:  9
# Total # of Tweets added:  979551
# -------------------
# -------------------
# Request #:  1964
# Requesting Time:  838
# Token:  b26v89c19zqg8o3foseufp4fdtwhxwlq7ru37cg001o59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufp4f7rf25joyb1p4593r1xi0t
# # of Tweets added from this response:  499
# # of users added from this response:  471
# # of Places added from this response:  10
# Total # of Tweets added:  980050
# -------------------
# -------------------
# Request #:  1965
# Requesting Time:  843
# Token:  b26v89c19zqg8o3foseufp4f7rf25joyb1p4593r1xi0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufp44mwxurdfh97bsc8mmlddh9
# # of Tweets added from this response:  499
# # of users added from this response:  458
# # of Places added from this response:  9
# Total # of Tweets added:  980549
# -------------------
# -------------------
# Request #:  1966
# Requesting Time:  847
# Token:  b26v89c19zqg8o3foseufp44mwxurdfh97bsc8mmlddh9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufp44gv37xk94swg2qdevsj43h
# # of Tweets added from this response:  498
# # of users added from this response:  467
# # of Places added from this response:  6
# Total # of Tweets added:  981047
# -------------------
# -------------------
# Request #:  1967
# Requesting Time:  851
# Token:  b26v89c19zqg8o3foseufp44gv37xk94swg2qdevsj43h
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn23ohgdpl7kq0ljppan8alq5
# # of Tweets added from this response:  500
# # of users added from this response:  466
# # of Places added from this response:  10
# Total # of Tweets added:  981547
# -------------------
# -------------------
# Request #:  1968
# Requesting Time:  856
# Token:  b26v89c19zqg8o3foseufn23ohgdpl7kq0ljppan8alq5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn23jxsm6r8iecdcuqgxgeqv1
# # of Tweets added from this response:  500
# # of users added from this response:  480
# # of Places added from this response:  7
# Total # of Tweets added:  982047
# -------------------
# -------------------
# Request #:  1969
# Requesting Time:  860
# Token:  b26v89c19zqg8o3foseufn23jxsm6r8iecdcuqgxgeqv1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn23dviuxys3vfvgpa8cacygt
# # of Tweets added from this response:  500
# # of users added from this response:  459
# # of Places added from this response:  7
# Total # of Tweets added:  982547
# -------------------
# -------------------
# Request #:  1970
# Requesting Time:  865
# Token:  b26v89c19zqg8o3foseufn23dviuxys3vfvgpa8cacygt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1sw2i7w1wvgh4icpswbyttp
# # of Tweets added from this response:  500
# # of users added from this response:  463
# # of Places added from this response:  9
# Total # of Tweets added:  983047
# -------------------
# -------------------
# Request #:  1971
# Requesting Time:  869
# Token:  b26v89c19zqg8o3foseufn1sw2i7w1wvgh4icpswbyttp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1srhzsezs8dspe5w51d0399
# # of Tweets added from this response:  499
# # of users added from this response:  469
# # of Places added from this response:  6
# Total # of Tweets added:  983546
# -------------------
# -------------------
# Request #:  1972
# Requesting Time:  873
# Token:  b26v89c19zqg8o3foseufn1srhzsezs8dspe5w51d0399
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1smyrnmzx655p9r306afx4t
# # of Tweets added from this response:  499
# # of users added from this response:  476
# # of Places added from this response:  8
# Total # of Tweets added:  984045
# -------------------
# -------------------
# Request #:  1973
# Requesting Time:  878
# Token:  b26v89c19zqg8o3foseufn1smyrnmzx655p9r306afx4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1i5494l426uvr09nihi76v1
# # of Tweets added from this response:  497
# # of users added from this response:  458
# # of Places added from this response:  11
# Total # of Tweets added:  984542
# -------------------
# -------------------
# Request #:  1974
# Requesting Time:  882
# Token:  b26v89c19zqg8o3foseufn1i5494l426uvr09nihi76v1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1i0k6cz5bohcwgz1kqppqpp
# # of Tweets added from this response:  498
# # of users added from this response:  471
# # of Places added from this response:  10
# Total # of Tweets added:  985040
# -------------------
# -------------------
# Request #:  1975
# Requesting Time:  886
# Token:  b26v89c19zqg8o3foseufn1i0k6cz5bohcwgz1kqppqpp
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1hw0b7pgfvpsagjp061pzel
# # of Tweets added from this response:  498
# # of users added from this response:  470
# # of Places added from this response:  4
# Total # of Tweets added:  985538
# -------------------
# -------------------
# Request #:  1976
# Requesting Time:  890
# Token:  b26v89c19zqg8o3foseufn1hw0b7pgfvpsagjp061pzel
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1hrgnosch4x0cb16kytyb99
# # of Tweets added from this response:  500
# # of users added from this response:  473
# # of Places added from this response:  8
# Total # of Tweets added:  986038
# -------------------
# -------------------
# Request #:  1977
# Requesting Time:  895
# Token:  b26v89c19zqg8o3foseufn1hrgnosch4x0cb16kytyb99
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn179pcftv5limo8b77lwvhx9
# # of Tweets added from this response:  500
# # of users added from this response:  482
# # of Places added from this response:  5
# Total # of Tweets added:  986538
# -------------------
# -------------------
# Request #:  1978
# Requesting Time:  899
# Token:  b26v89c19zqg8o3foseufn179pcftv5limo8b77lwvhx9
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn1755h55adbrc7otfg64l7r1
# # of Tweets added from this response:  499
# # of users added from this response:  472
# # of Places added from this response:  8
# Total # of Tweets added:  987037
# -------------------
# -------------------
# Request #:  1979
# Requesting Time:  903
# Token:  b26v89c19zqg8o3foseufn1755h55adbrc7otfg64l7r1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn170kyzeifc5fr6sxun8sk1p
# # of Tweets added from this response:  499
# # of users added from this response:  472
# # of Places added from this response:  14
# Total # of Tweets added:  987536
# -------------------
# -------------------
# Request #:  1980
# Requesting Time:  907
# Token:  b26v89c19zqg8o3foseufn170kyzeifc5fr6sxun8sk1p
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0wk9ahjvuxdjutcuiwqhuv1
# # of Tweets added from this response:  498
# # of users added from this response:  482
# # of Places added from this response:  10
# Total # of Tweets added:  988034
# -------------------
# -------------------
# Request #:  1981
# Requesting Time:  912
# Token:  b26v89c19zqg8o3foseufn0wk9ahjvuxdjutcuiwqhuv1
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0we8akt0bsni6jz632v2ge5
# # of Tweets added from this response:  498
# # of users added from this response:  476
# # of Places added from this response:  5
# Total # of Tweets added:  988532
# -------------------
# -------------------
# Request #:  1982
# Requesting Time:  916
# Token:  b26v89c19zqg8o3foseufn0we8akt0bsni6jz632v2ge5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0wb5k2ongvtxjl8dfplumwt
# # of Tweets added from this response:  497
# # of users added from this response:  471
# # of Places added from this response:  7
# Total # of Tweets added:  989029
# -------------------
# -------------------
# Request #:  1983
# Requesting Time:  920
# Token:  b26v89c19zqg8o3foseufn0wb5k2ongvtxjl8dfplumwt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0w6mjnjkj5gejq2l9izcfwd
# # of Tweets added from this response:  498
# # of users added from this response:  475
# # of Places added from this response:  7
# Total # of Tweets added:  989527
# -------------------
# -------------------
# Request #:  1984
# Requesting Time:  924
# Token:  b26v89c19zqg8o3foseufn0w6mjnjkj5gejq2l9izcfwd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0lotqr7aw0kxc6vlhd7788t
# # of Tweets added from this response:  499
# # of users added from this response:  472
# # of Places added from this response:  11
# Total # of Tweets added:  990026
# -------------------
# -------------------
# Request #:  1985
# Requesting Time:  929
# Token:  b26v89c19zqg8o3foseufn0lotqr7aw0kxc6vlhd7788t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0lkaids7ozy1iyzqh08ylbx
# # of Tweets added from this response:  499
# # of users added from this response:  479
# # of Places added from this response:  7
# Total # of Tweets added:  990525
# -------------------
# -------------------
# Request #:  1986
# Requesting Time:  933
# Token:  b26v89c19zqg8o3foseufn0lkaids7ozy1iyzqh08ylbx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0lfq0b8qa7wbdjkz8dqzhq5
# # of Tweets added from this response:  498
# # of users added from this response:  464
# # of Places added from this response:  6
# Total # of Tweets added:  991023
# -------------------
# -------------------
# Request #:  1987
# Requesting Time:  937
# Token:  b26v89c19zqg8o3foseufn0lfq0b8qa7wbdjkz8dqzhq5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0axwzit57v38ckvw7isq5q5
# # of Tweets added from this response:  500
# # of users added from this response:  477
# # of Places added from this response:  7
# Total # of Tweets added:  991523
# -------------------
# -------------------
# Request #:  1988
# Requesting Time:  942
# Token:  b26v89c19zqg8o3foseufn0axwzit57v38ckvw7isq5q5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0auvbc38k9akkscq0tsvlvh
# # of Tweets added from this response:  500
# # of users added from this response:  474
# # of Places added from this response:  8
# Total # of Tweets added:  992023
# -------------------
# -------------------
# Request #:  1989
# Requesting Time:  946
# Token:  b26v89c19zqg8o3foseufn0auvbc38k9akkscq0tsvlvh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0aqbns3ulhujjr6of6wsinx
# # of Tweets added from this response:  497
# # of users added from this response:  452
# # of Places added from this response:  12
# Total # of Tweets added:  992520
# -------------------
# -------------------
# Request #:  1990
# Requesting Time:  950
# Token:  b26v89c19zqg8o3foseufn0aqbns3ulhujjr6of6wsinx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn0als0foyyndax690i0arssd
# # of Tweets added from this response:  500
# # of users added from this response:  468
# # of Places added from this response:  11
# Total # of Tweets added:  993020
# -------------------
# -------------------
# Request #:  1991
# Requesting Time:  955
# Token:  b26v89c19zqg8o3foseufn0als0foyyndax690i0arssd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn005gjrrw087eoblik2zqw71
# # of Tweets added from this response:  498
# # of users added from this response:  478
# # of Places added from this response:  10
# Total # of Tweets added:  993518
# -------------------
# -------------------
# Request #:  1992
# Requesting Time:  959
# Token:  b26v89c19zqg8o3foseufn005gjrrw087eoblik2zqw71
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufn000xj9eg003etbmsrhu3vjx
# # of Tweets added from this response:  500
# # of users added from this response:  474
# # of Places added from this response:  10
# Total # of Tweets added:  994018
# -------------------
# -------------------
# Request #:  1993
# Requesting Time:  963
# Token:  b26v89c19zqg8o3foseufn000xj9eg003etbmsrhu3vjx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzzweqa3el3fqz5i7jzig6m5
# # of Tweets added from this response:  499
# # of users added from this response:  474
# # of Places added from this response:  8
# Total # of Tweets added:  994517
# -------------------
# -------------------
# Request #:  1994
# Requesting Time:  968
# Token:  b26v89c19zqg8o3foseufmzzweqa3el3fqz5i7jzig6m5
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzztd2axeqz3jalackb3nx4t
# # of Tweets added from this response:  499
# # of users added from this response:  473
# # of Places added from this response:  7
# Total # of Tweets added:  995016
# -------------------
# -------------------
# Request #:  1995
# Requesting Time:  972
# Token:  b26v89c19zqg8o3foseufmzztd2axeqz3jalackb3nx4t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzpbk1nw3podmapajirhtzel
# # of Tweets added from this response:  500
# # of users added from this response:  451
# # of Places added from this response:  15
# Total # of Tweets added:  995516
# -------------------
# -------------------
# Request #:  1996
# Requesting Time:  976
# Token:  b26v89c19zqg8o3foseufmzpbk1nw3podmapajirhtzel
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzp8hq6y2j7qaz4tci757ngd
# # of Tweets added from this response:  499
# # of users added from this response:  470
# # of Places added from this response:  5
# Total # of Tweets added:  996015
# -------------------
# -------------------
# Request #:  1997
# Requesting Time:  981
# Token:  b26v89c19zqg8o3foseufmzp8hq6y2j7qaz4tci757ngd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzp3yppn7kkaww008r1z2n3x
# # of Tweets added from this response:  499
# # of users added from this response:  476
# # of Places added from this response:  7
# Total # of Tweets added:  996514
# -------------------
# -------------------
# Request #:  1998
# Requesting Time:  985
# Token:  b26v89c19zqg8o3foseufmzp3yppn7kkaww008r1z2n3x
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzem6c9kx6j7679zzougx8cd
# # of Tweets added from this response:  499
# # of users added from this response:  471
# # of Places added from this response:  12
# Total # of Tweets added:  997013
# -------------------
# -------------------
# Request #:  1999
# Requesting Time:  989
# Token:  b26v89c19zqg8o3foseufmzem6c9kx6j7679zzougx8cd
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzej4gd9bloqspkdhj19ycfx
# # of Tweets added from this response:  496
# # of users added from this response:  476
# # of Places added from this response:  10
# Total # of Tweets added:  997509
# -------------------
# -------------------
# Request #:  2000
# Requesting Time:  993
# Token:  b26v89c19zqg8o3foseufmzej4gd9bloqspkdhj19ycfx
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzeg1xikl37980csr7fgws59
# # of Tweets added from this response:  500
# # of users added from this response:  476
# # of Places added from this response:  6
# Total # of Tweets added:  998009
# -------------------
# -------------------
# Request #:  2001
# Requesting Time:  998
# Token:  b26v89c19zqg8o3foseufmzeg1xikl37980csr7fgws59
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmzebip8fiwgpqwpq55ok0ygt
# # of Tweets added from this response:  500
# # of users added from this response:  469
# # of Places added from this response:  5
# Total # of Tweets added:  998509
# -------------------
# -------------------
# Request #:  2002
# Requesting Time:  1002
# Token:  b26v89c19zqg8o3foseufmzebip8fiwgpqwpq55ok0ygt
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseufmze8gtb11k0sslm642ha9ojh
# # of Tweets added from this response:  499
# # of users added from this response:  470
# # of Places added from this response:  5
# Total # of Tweets added:  999008
# -------------------
# -------------------
# Request #:  2003
# Requesting Time:  1007
# Token:  b26v89c19zqg8o3foseufmze8gtb11k0sslm642ha9ojh
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseu10mp1w1rgkp0ea1rs4wnyqu0t
# # of Tweets added from this response:  497
# # of users added from this response:  463
# # of Places added from this response:  8
# Total # of Tweets added:  999505
# -------------------
# -------------------
# Request #:  2004
# Requesting Time:  1011
# Token:  b26v89c19zqg8o3foseu10mp1w1rgkp0ea1rs4wnyqu0t
# Endpoint Response Code: 200
# Next Token:  b26v89c19zqg8o3foseu10moxd8wiamngziw9nhda6q2l
# # of Tweets added from this response:  499
# # of users added from this response:  474
# # of Places added from this response:  5
# Total # of Tweets added:  1000004
# -------------------
# Total number of results:  1000004

# %%
# GET USERS
userlist=['SkyNews','nypost','CNN','nytimes','thehill','Reuters','washingtonpost','ABC','MSNBC','AP','NBCNews','inquirerdotnet','CBSNews','BBCNews','cnnbrk','CP24','ANI','FoxNews','NPR','ABSCBNNews','CNNPolitics','CTVNews','nowthisnews','SkyNewsBreak','dwnews','GMB','TMZ','LBC','ABC7','BBCBreaking','talkRADIO','BNODesk','latimes','newsmax','WSJ','BBCWorld','business','Independent','guardian','CNBC','gmanews','News24','ClayTravis','thedailybeast','politico','SMTOWNGLOBAL','rapplerdotcom','THR','BreitbartNews','Variety','DailyMailUK','therecount','itvnews','TIME','eNCA','SkySportsNews','cnnphilippines','globalnews','cnni','CBCAlerts','CNBCnow','rtenews','CBCNews','MobilePunch','KTLA','MailOnline','ndtv','SportsCenter','TorontoStar','Complex','SkyNewsAust','AFP','HuffPost','USATODAY','RT_com','theblaze','Public_Citizen','Newsweek','TheEconomist','axios','abcnews','NYDailyNews','DailyMail','TheSun','PhilippineStar','nprpolitics','OANN','BusinessInsider','BBCPolitics','ANCALERTS','CBCToronto','globaltimesnews','EpochTimes','japantimes','dailystar','TheLeadCNN','Daily_Express','DailyMirror','VibeMagazine','Forbes','Quicktake','guardiannews','BW','BuzzFeedNews','propublica','BBCScotlandNews','FOXLA','TheTorontoSun','BBCBreakfast','TODAYshow','WalesOnline','CTVToronto','ABCPolitics','newscomauHQ','nationalpost','STVNews','SunSentinel','Independent_ie','BBCWalesNews','NBCLA','StarTribune','AP_Politics','PhilstarNews','bbc5live','KUSINews','GMA','9NewsAUS','CityNewsTO','people','AJEnglish','theage','MENnewsdesk','smh','citizentvkenya','abc7newsbayarea','TimesLIVE','ntvkenya','ChannelNewsAsia','NewsHour','globeandmail','CBSEveningNews','KTVU','freep','NBCPolitics','KDKA','Channel4News','SABCNews','htTweets','fox7austin','nytpolitics','FinancialTimes','YahooNews','PTI_News','CBSLA','LBCNews','ABC7NY','WashTimes','denverpost','IrishTimes','Reuters_Health','chicagotribune','MiamiHerald','TheView','orlandosentinel','bopinion','sfchronicle','BostonGlobe','thetimes','ABCWorldNews','BBCSport','KFOX14','abc3340','XHNews','TheDailyShow','SBSNews','680NEWS','timesofindia','CBSMornings','9NewsSyd','MetroUK','ajplus','GlobalEdmonton','cbcnewsbc','TimesNow','TheOnion','CTVNationalNews','FOX10Phoenix','PremiumTimesng','WIONews','vanguardngrnews','KATUNews','IndiaToday','9NewsMelb','ctvottawa','theheraldsun','FOX9','ScottishSun','komonews','CityNewsVAN','standardnews','seattletimes','Jerusalem_Post','GlobalBC','ESPNCFB','8NewsNow','ntvuganda','statnews','SCMPNews','MeetThePress','BelTel','MirrorPolitics','FOX5Vegas','XXL','TB_Times','CGTNOfficial','detroitnews','kron4news','republic','NewYorker','BreakingNews','NationAfrica','ABC7Chicago','calgaryherald','DailyPostNGR','azcentral','OpIndia_com','IOL','SkySportsPL','FOX2News','TexasTribune','ewnupdates','bpolitics','cspanwj','ctvedmonton','NBCPhiladelphia','WCCO','manilabulletin','6abc','CTVCalgary','fox5dc','FOX13News','BuzzFeed','BBCNewsNI','Oregonian','CBCOttawa','voxdotcom','PulseNigeria247','TPostMillennial','ajc','RebelNewsOnline','newscientist','VanityFair','thenewsoncnbc','abc13houston','abc15','KING5Seattle','wbz','DEADLINE','FOX29philly','ABC30','CityAM','RNCResearch','IGN','MLive','straits_times','CTVVancouver','thejournal_ie','Investingcom','WCVB','bmj_latest','ABC11_WTVD','TheNationNews','HuffPostPol','TheRoot','ChinaDaily','WRAL','fox13seattle','azfamily','KHOU','CNNHeroes','ReutersUK','NewstalkFM','nytimesworld','latimeshealth','NEWSTALK1010','5_News','nbstv','malaysiakini','tes','newsbusters','wsvn','wsbtv','WGRZ','FT','wxyzdetroit','njdotcom','WFLA','democracynow','globalnewsto','FOX4','nbcbayarea','euronews','NigeriaNewsdesk','ndtvfeed','Local4News','BBCNewsnight','CBCPolitics','the_hindu','10TV','NY1','wjz','Saudi_Gazette','nytopinion','KIRO7Seattle','blogTO','CBCCalgary','WPXI','ctvqp','FOX5Atlanta','TPM','PolitiFact','AlArabiya_Eng','7News','ComplexSports','AP_Europe','WSMV','YahooFinance','CNNnewsroom','CBSMiami','news4buffalo','TheAtlantic','NewDay','nbcchicago','9NEWS','kare11','NBCDFW','NewshubNZ','RealSkipBayless','usatodaysports','DenverChannel','GuardianAus','CTVMontreal','7NewsMelbourne','SputnikInt','FoxBusiness','starsandstripes','OttawaCitizen','nzherald','ksatnews','edmontonjournal','qikipedia','77WABCradio','ITVWales','NBCNightlyNews','kcranews','FOXNashville','irishexaminer','BET','BBCNWT','GlobalNational','CBCTheNational','enews','7NewsSydney','FaceTheNation','fox32news','BloombergAsia','ReutersBiz','fox13','amazonnews','MPRnews','bostonherald','fox5sandiego','IrishTimesWorld','TheAVClub','dallasnews','BBCr4today','CBSDenver','WSJopinion','nbcsandiego','fox12oregon','KVUE','KXAN_News','NBCNewYork','12News','TimesofIsrael','hkfp','ewnreporter','Tennessean','aldotcom','11thHour','NEJM','Local12','daily_trust','SFGate','staronline','DailyMonitor','clevelanddotcom','DailyMailCeleb']
def create_user_url(userlist):
    # Specify the usernames that you want to lookup below
    # You can enter up to 100 comma-separated values.
    usernames = f"usernames={','.join(userlist)}"
    user_fields = "user.fields=location"
    # User fields are adjustable, options include:
    # created_at, description, entities, id, location, name,
    # pinned_tweet_id, profile_image_url, protected,
    # public_metrics, url, username, verified, and withheld
    url = "https://api.twitter.com/2/users/by?{}&{}".format(usernames, user_fields)
    return url


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2UserLookupPython"
    return r


def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth,)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()

url = create_user_url(userlist[:10])
json_response = connect_to_endpoint(url)
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# 200
# {
#     "data": [
#         {
#             "id": "7587032",
#             "location": "London, UK",
#             "name": "Sky News",
#             "username": "SkyNews"
#         },
#         {
#             "id": "17469289",
#             "location": "New York, NY",
#             "name": "New York Post",
#             "username": "nypost"
#         },
#         {
#             "id": "759251",
#             "name": "CNN",
#             "username": "CNN"
#         },
#         {
#             "id": "807095",
#             "location": "New York City",
#             "name": "The New York Times",
#             "username": "nytimes"
#         },
#         {
#             "id": "1917731",
#             "location": "Washington, DC",
#             "name": "The Hill",
#             "username": "thehill"
#         },
#         {
#             "id": "1652541",
#             "location": "Around the world",
#             "name": "Reuters",
#             "username": "Reuters"
#         },
#         {
#             "id": "2467791",
#             "location": "Washington, DC",
#             "name": "The Washington Post",
#             "username": "washingtonpost"
#         },
#         {
#             "id": "28785486",
#             "location": "New York City / Worldwide",
#             "name": "ABC News",
#             "username": "ABC"
#         },
#         {
#             "id": "2836421",
#             "name": "MSNBC",
#             "username": "MSNBC"
#         },
#         {
#             "id": "51241574",
#             "location": "Global",
#             "name": "The Associated Press",
#             "username": "AP"
#         }
#     ]
# }

# %%
news_accounts = pd.DataFrame(columns=['username', 'location'])
for cnt in range(int(np.ceil(len(userlist)/100))):
    url = create_user_url(userlist[cnt*100:(cnt+1)*100])
    json_response = connect_to_endpoint(url)
    for user in (json_response['data']):
        username = user['username']
        if 'location' in user.keys():
            location = user['location']
        else:
            location = ''
        news_accounts.loc[news_accounts.shape[0]] = [username, location]
# Out:
# 200
# 200
# 200
# 200

# %%
geolocator = Nominatim(user_agent="my_request")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
news_accounts['geotag'] = news_accounts['location'].apply(geocode)
news_accounts['country'] = news_accounts['geotag'].apply(lambda x: x.address.split(',')[-1].strip() if x else None)
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('Arlington, VA | New York, NY',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('Arlington, VA | New York, NY',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('Arlington, VA | New York, NY',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=Arlington%2C+VA+%7C+New+York%2C+NY&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('📺 6:30 p.m. ET',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('📺 6:30 p.m. ET',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter swallowed an error after 2 retries. Called with (*('📺 6:30 p.m. ET',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=%F0%9F%93%BA+6%3A30+p.m.+ET&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (0/2 tries). Called with (*('London / New York / Hong Kong',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London+%2F+New+York+%2F+Hong+Kong&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London+%2F+New+York+%2F+Hong+Kong&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London+%2F+New+York+%2F+Hong+Kong&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# RateLimiter caught an error, retrying (1/2 tries). Called with (*('London / New York / Hong Kong',), **{}).
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 445, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 3, in raise_from
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 440, in _make_request
#     httplib_response = conn.getresponse()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 1347, in getresponse
#     response.begin()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 307, in begin
#     version, status, reason = self._read_status()
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\http\client.py", line 268, in _read_status
#     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# socket.timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 699, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 447, in _make_request
#     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 336, in _raise_timeout
#     raise ReadTimeoutError(
# urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 439, in send
#     resp = conn.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 783, in urlopen
#     return self.urlopen(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\connectionpool.py", line 755, in urlopen
#     retries = retries.increment(
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\urllib3\util\retry.py", line 574, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London+%2F+New+York+%2F+Hong+Kong&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 387, in _request
#     resp = self.session.get(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 555, in get
#     return self.request('GET', url, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 542, in request
#     resp = self.send(prep, **send_kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\sessions.py", line 655, in send
#     r = adapter.send(request, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\requests\adapters.py", line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London+%2F+New+York+%2F+Hong+Kong&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\extra\rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\nominatim.py", line 297, in geocode
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\geocoders\base.py", line 360, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 377, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "C:\Users\f.braulio\Anaconda3\envs\ugpn-covid-emotions\lib\site-packages\geopy\adapters.py", line 399, in _request
#     raise GeocoderUnavailable(message)
# geopy.exc.GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=London+%2F+New+York+%2F+Hong+Kong&format=json&limit=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
news_accounts[['username', 'location', 'country']].to_csv("./../data/processed/covid_usern_places.csv", index=False, sep=';')

# %%
#Loop through each user
news_accounts = pd.DataFrame(columns=['username', 'location'])
for user in (json_response['data']):
    username = user['username']
    if 'location' in user.keys():
        location = user['location']
    else:
        location = ''
    news_accounts.loc[news_accounts.shape[0]] = [username, location]

# %%
news_accounts
# Out:
#          username                   location
# 0         SkyNews                 London, UK
# 1          nypost               New York, NY
# 2             CNN
# 3         nytimes              New York City
# 4         thehill             Washington, DC
# 5         Reuters           Around the world
# 6  washingtonpost             Washington, DC
# 7             ABC  New York City / Worldwide
# 8           MSNBC
# 9              AP                     Global
